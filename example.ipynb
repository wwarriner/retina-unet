# %% [markdown]
# ## Imports

# %%
from retinal_fundus_unet import train, test, display_predictions, get_out_folder
from lib.config_snake.config import ConfigFile
from matplotlib import pyplot as plt

# %% [markdown]
# ## Config

# %%
config = ConfigFile("config.json")
config.training.epochs = 5

# %% [markdown]
# ## Train

# %%
train(config)
# Out:
# Train on 900 samples, validate on 101 samples
# Epoch 1/5
# 896/900 [============================>.] - ETA: 0s - loss: 0.1598 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00
# Epoch 00001: val_loss improved from inf to 0.16256, saving model to out\test\test_best_weights.h5
# 900/900 [==============================] - 5s 6ms/sample - loss: 0.1598 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00 - val_loss: 0.1626 - val_mean_io_u_1: 0.2500 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 896/900 [============================>.] - ETA: 0s - loss: 0.1564 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00
# Epoch 00002: val_loss improved from 0.16256 to 0.16212, saving model to out\test\test_best_weights.h5
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.1563 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00 - val_loss: 0.1621 - val_mean_io_u_1: 0.2500 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 896/900 [============================>.] - ETA: 0s - loss: 0.1566 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00
# Epoch 00003: val_loss did not improve from 0.16212
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.1565 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00 - val_loss: 0.1627 - val_mean_io_u_1: 0.2500 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 896/900 [============================>.] - ETA: 0s - loss: 0.1570 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00
# Epoch 00004: val_loss improved from 0.16212 to 0.16022, saving model to out\test\test_best_weights.h5
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.1568 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00 - val_loss: 0.1602 - val_mean_io_u_1: 0.2500 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 896/900 [============================>.] - ETA: 0s - loss: 0.1540 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00
# Epoch 00005: val_loss did not improve from 0.16022
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.1539 - mean_io_u_1: 0.2500 - accuracy: 0.0000e+00 - val_loss: 0.1628 - val_mean_io_u_1: 0.2500 - val_accuracy: 0.0000e+00

# %% [markdown]
# ## Test

# %%
test(config)

# %% [markdown]
# ## Display

# %%
_ = display_predictions(plt.imshow, config)
fig = plt.gcf()
fig.set_size_inches(20, 20)
ax = plt.gca()
ax.axis("off")

out = "example_result.png"
plt.savefig(str(out))
