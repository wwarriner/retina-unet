# %% [markdown]
# ## Imports

# %%
from retinal_fundus_unet import train, test, display_predictions, get_out_folder
from lib.config_snake.config import ConfigFile
from matplotlib import pyplot as plt

# %% [markdown]
# ## Config

# %%
config = ConfigFile("config.json")
config.training.unet.level_count = 2
config.training.patch_count = 10000
config.training.epochs = 5

# %% [markdown]
# ## Train

# %%
train(config)
# Out:
# Train on 89996 samples, validate on 10000 samples
# Epoch 1/250
# 89984/89996 [============================>.] - ETA: 0s - loss: 0.0704 - mean_io_u_5: 0.2500 - accuracy: 6.1739e-07
# Epoch 00001: val_loss improved from inf to 0.05385, saving model to out\test\test_best_weights.h5
# 89996/89996 [==============================] - 141s 2ms/sample - loss: 0.0704 - mean_io_u_5: 0.2500 - accuracy: 6.1731e-07 - val_loss: 0.0538 - val_mean_io_u_5: 0.2500 - val_accuracy: 0.0000e+00
# Epoch 2/250
# 89984/89996 [============================>.] - ETA: 0s - loss: 0.0535 - mean_io_u_5: 0.2500 - accuracy: 5.5517e-06
# Epoch 00002: val_loss improved from 0.05385 to 0.04835, saving model to out\test\test_best_weights.h5
# 89996/89996 [==============================] - 142s 2ms/sample - loss: 0.0535 - mean_io_u_5: 0.2500 - accuracy: 5.5510e-06 - val_loss: 0.0483 - val_mean_io_u_5: 0.2500 - val_accuracy: 8.9627e-06
# Epoch 3/250
# ...

# %% [markdown]
# ## Test

# %%
test(config)

# %% [markdown]
# ## Display

# %%
_ = display_predictions(plt.imshow, config)
fig = plt.gcf()
fig.set_size_inches(20, 20)
ax = plt.gca()
ax.axis("off")

out = "example_result.png"
plt.savefig(str(out))
